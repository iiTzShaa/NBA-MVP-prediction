# %%
import warnings
import pandas as pd


warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
mvps = pd.read_csv("mvps.csv")

# %%
mvps
# Out:
#      Unnamed: 0 Rank           Player  Age   Tm  First  Pts Won  Pts Max  \
# 0             0    1   Michael Jordan   27  CHI     77      891      960
# 1             1    2    Magic Johnson   31  LAL     10      497      960
# 2             2    3   David Robinson   25  SAS      6      476      960
# 3             3    4  Charles Barkley   27  PHI      2      222      960
# 4             4    5      Karl Malone   27  UTA      0      142      960
# ..          ...  ...              ...  ...  ...    ...      ...      ...
# 494           8    9    Stephen Curry   34  GSW      0        5     1000
# 495           9   10     Jimmy Butler   33  MIA      0        3     1000
# 496          10   11     De'Aaron Fox   25  SAC      0        2     1000
# 497          11  12T    Jalen Brunson   26  NYK      0        1     1000
# 498          12  12T        Ja Morant   23  MEM      0        1     1000
#
#      Share   G  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  \
# ...

# %%
mvps= mvps[["Player" , "Year" , "Pts Won", "Share"]]

# %%
mvps = mvps.copy()

# Replace the player names
mvps['Player'] = mvps['Player'].replace({
    'Nikola JokiÄ': 'Nikola Jokić',
    'Luka DonÄiÄ': 'Luka Dončić',
    'Goran DragiÄ': 'Goran Dragić',
    'Manu GinÃ³bili': 'Manu Ginóbili',
    'Peja StojakoviÄ': 'Peja Stojaković'
})

# %%
mvps
# Out:
#               Player  Year  Pts Won  Share
# 0     Michael Jordan  1991      891  0.928
# 1      Magic Johnson  1991      497  0.518
# 2     David Robinson  1991      476  0.496
# 3    Charles Barkley  1991      222  0.231
# 4        Karl Malone  1991      142  0.148
# ..               ...   ...      ...    ...
# 494    Stephen Curry  2023        5  0.005
# 495     Jimmy Butler  2023        3  0.003
# 496     De'Aaron Fox  2023        2  0.002
# 497    Jalen Brunson  2023        1  0.001
# 498        Ja Morant  2023        1  0.001
#
# [499 rows x 4 columns]

# %%
players =pd.read_csv("players.csv")

# %%
players.head(30)
# Out:
#     Unnamed: 0  Rk              Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0            0   1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3  ...
# 1            1   2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  ...
# 2            2   3          Mark Acres   C  28  ORL  68   0  19.3  1.6  ...
# 3            3   4       Michael Adams  PG  28  DEN  66  66  35.5  8.5  ...
# 4            4   5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  ...
# 5            5   6         Danny Ainge  SG  31  POR  80   0  21.4  4.2  ...
# 6            6   7         Mark Alarie  PF  27  WSB  42   1  14.0  2.4  ...
# 7            7   8        Steve Alford  PG  26  DAL  34   0   6.9  1.7  ...
# 8            8   9       Greg Anderson  PF  26  TOT  68   2  13.6  1.7  ...
# 9            9   9       Greg Anderson  PF  26  MIL  26   0   9.5  1.0  ...
# 10          10   9       Greg Anderson  PF  26  NJN   1   0  18.0  4.0  ...
# ...

# %%
players.head(50)
# Out:
#     Unnamed: 0  Rk              Player    Pos  Age   Tm   G  GS    MP   FG  \
# 0            0   1      Alaa Abdelnaby     PF   22  POR  43   0   6.7  1.3
# 1            1   2  Mahmoud Abdul-Rauf     PG   21  DEN  67  19  22.5  6.2
# 2            2   3          Mark Acres      C   28  ORL  68   0  19.3  1.6
# 3            3   4       Michael Adams     PG   28  DEN  66  66  35.5  8.5
# 4            4   5        Mark Aguirre     SF   31  DET  78  13  25.7  5.4
# 5            5   6         Danny Ainge     SG   31  POR  80   0  21.4  4.2
# 6            6   7         Mark Alarie     PF   27  WSB  42   1  14.0  2.4
# 7            7   8        Steve Alford     PG   26  DAL  34   0   6.9  1.7
# 8            8   9       Greg Anderson     PF   26  TOT  68   2  13.6  1.7
# 9            9   9       Greg Anderson     PF   26  MIL  26   0   9.5  1.0
# 10          10   9       Greg Anderson     PF   26  NJN   1   0  18.0  4.0
# ...

# %%
players["Player"] =players["Player"].str.replace("*","",regex = False)

# %%
players["Player"].head(50)
# Out:
# 0         Alaa Abdelnaby
# 1     Mahmoud Abdul-Rauf
# 2             Mark Acres
# 3          Michael Adams
# 4           Mark Aguirre
# 5            Danny Ainge
# 6            Mark Alarie
# 7           Steve Alford
# 8          Greg Anderson
# 9          Greg Anderson
# 10         Greg Anderson
# 11         Greg Anderson
# 12         Nick Anderson
# 13          Ron Anderson
# 14       Willie Anderson
# 15        Michael Ansley
# 16        B.J. Armstrong
# 17         Vincent Askew
# 18          Keith Askins
# 19           Miloš Babić
# 20          Thurl Bailey
# 21           Cedric Ball
# 22         Ken Bannister
# 23       Charles Barkley
# 24           Dana Barros
# 25           John Battle
# 26          Kenny Battle
# 27          Kenny Battle
# 28          Kenny Battle
# 29       William Bedford
# 30       Benoit Benjamin
# 31       Benoit Benjamin
# 32       Benoit Benjamin
# 33       Winston Bennett
# 34            Larry Bird
# 35      Rolando Blackman
# 36          Lance Blanks
# ...

# %%
players.tail(20)
players.isnull().sum()
# Out:
# Unnamed: 0       0
# Rk               0
# Player           0
# Pos              0
# Age              0
# Tm               0
# G                0
# GS               0
# MP               0
# FG               0
# FGA              0
# FG%            109
# 3P               0
# 3PA              0
# 3P%           2880
# 2P               0
# 2PA              0
# 2P%            183
# eFG%           109
# FT               0
# FTA              0
# FT%            928
# ORB              0
# DRB              0
# TRB              0
# AST              0
# STL              0
# BLK              0
# TOV              0
# PF               0
# PTS              0
# Year             0
# dtype: int64

# %%
players.groupby(["Player","Year"]).get_group(("Greg Anderson" , 1991))
# Out:
#     Unnamed: 0 Rk         Player Pos Age   Tm   G GS    MP   FG  ...  ORB  \
# 8            8  9  Greg Anderson  PF  26  TOT  68  2  13.6  1.7  ...  1.4
# 9            9  9  Greg Anderson  PF  26  MIL  26  0   9.5  1.0  ...  1.0
# 10          10  9  Greg Anderson  PF  26  NJN   1  0  18.0  4.0  ...  4.0
# 11          11  9  Greg Anderson  PF  26  DEN  41  2  16.1  2.1  ...  1.6
#
#     DRB  TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 8   3.3  4.7  0.2  0.5  0.7  1.2  2.1  4.3  1991
# 9   1.9  2.9  0.1  0.3  0.3  0.8  1.1  2.7  1991
# 10  2.0  6.0  1.0  2.0  0.0  1.0  4.0  8.0  1991
# 11  4.1  5.8  0.3  0.6  0.9  1.5  2.6  5.2  1991
#
# [4 rows x 32 columns]

# %%
def single_row(df):
    if df.shape[0] ==1:
        return df
    else:
        row= df[df["Tm"] == "TOT"] 
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row

# %%
players =players.groupby(["Player","Year"]).apply(single_row)

# %%
players.head(20)
players.tail(20)
# Out:
#                                 Unnamed: 0   Rk                Player Pos Age  \
# Player               Year
# Šarūnas Marčiulionis 1991 256          256  215  Šarūnas Marčiulionis  SG  26
#                      1992 726          267  218  Šarūnas Marčiulionis  SG  27
#                      1993 1189         254  220  Šarūnas Marčiulionis  SF  28
#                      1995 2164         262  224  Šarūnas Marčiulionis  SG  30
#                      1996 2666         293  228  Šarūnas Marčiulionis  SG  31
#                      1997 3258         320  233  Šarūnas Marčiulionis  SG  32
# Žan Tabak            1995 2311         409  355             Žan Tabak   C  24
#                      1996 2862         489  376             Žan Tabak   C  25
#                      1997 3461         523  385             Žan Tabak   C  26
#                      1998 4013         480  381             Žan Tabak   C  27
#                      2000 5080         453  387             Žan Tabak   C  29
# ...

# %%
players.index = players.index.droplevel()
players.index = players.index.droplevel()

# %%
players
players.isnull().sum()
player_to_check = 'Charles Barkley'

# Check if the player exists
player_rows = mvps[mvps['Player'] == player_to_check]
print(player_rows)
# Check if the player exists
player_rows = players[players['Player'] == player_to_check]
print(player_rows)
# Out:
#               Player  Year  Pts Won  Share
# 3    Charles Barkley  1991      222  0.231
# 31   Charles Barkley  1992       18  0.019
# 37   Charles Barkley  1993      835  0.852
# 60   Charles Barkley  1994        5  0.005
# 73   Charles Barkley  1995       96  0.091
# 94   Charles Barkley  1996        8  0.007
# 115  Charles Barkley  1997        2  0.002
#       Unnamed: 0  Rk           Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 23            23  21  Charles Barkley  SF  27  PHI  67  67  37.3  9.9  ...
# 487           28  25  Charles Barkley  SF  28  PHI  75  75  38.4  8.3  ...
# 964           29  24  Charles Barkley  PF  29  PHO  76  76  37.6  9.4  ...
# 1431          29  24  Charles Barkley  PF  30  PHO  65  65  35.4  8.0  ...
# 1923          21  20  Charles Barkley  PF  31  PHO  68  66  35.0  8.1  ...
# 2398          25  22  Charles Barkley  PF  32  PHO  71  71  37.1  8.2  ...
# 2966          28  22  Charles Barkley  PF  33  HOU  53  53  37.9  6.3  ...
# ...

# %%
players[players["Player"] == "Greg Anderson"]
players.tail(50)
players.isnull().sum()
# Out:
# Unnamed: 0       0
# Rk               0
# Player           0
# Pos              0
# Age              0
# Tm               0
# G                0
# GS               0
# MP               0
# FG               0
# FGA              0
# FG%             61
# 3P               0
# 3PA              0
# 3P%           2102
# 2P               0
# 2PA              0
# 2P%            105
# eFG%            61
# FT               0
# FTA              0
# FT%            545
# ORB              0
# DRB              0
# TRB              0
# AST              0
# STL              0
# BLK              0
# TOV              0
# PF               0
# PTS              0
# Year             0
# dtype: int64

# %%
combaind =players.merge(mvps, how="outer" ,on=["Player", "Year"])

# %%
combaind.head(5)
combaind.tail(20)
combaind.isnull().sum()
rows_with_nans = combaind[combaind['Tm'].isnull()]
print(rows_with_nans)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Rk, Player, Pos, Age, Tm, G, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS, Year, Pts Won, Share]
# Index: []
#
# [0 rows x 34 columns]

# %%
combaind[combaind["Pts Won"]>0]
# Out:
#        Unnamed: 0   Rk         Player    Pos Age   Tm   G  GS    MP    FG  \
# 206           312  231   Al Jefferson      C  29  CHA  73  73  35.0   9.6
# 360           243  178  Allen Iverson     PG  21  PHI  76  74  40.1   8.2
# 362           222  178  Allen Iverson     SG  23  PHI  48  48  41.5   9.1
# 363           223  187  Allen Iverson     SG  24  PHI  70  70  40.8  10.4
# 364           227  186  Allen Iverson     SG  25  PHI  71  71  42.0  10.7
# ...           ...  ...            ...    ...  ..  ...  ..  ..   ...   ...
# 14689          85   70   Vince Carter     SF  23  TOR  82  82  38.1   9.6
# 14690          76   65   Vince Carter     SF  24  TOR  75  75  39.7  10.2
# 14694         103   75   Vince Carter  SF-SG  28  NJN  77  76  36.7   9.0
# 15082         364  276       Yao Ming      C  23  HOU  82  82  32.8   6.5
# 15087         378  283       Yao Ming      C  28  HOU  77  77  33.6   7.4
#
#        ...   TRB  AST  STL  BLK  TOV   PF   PTS  Year Pts Won  Share
# ...

# %%
combaind[["Pts Won","Share" ]]=combaind[["Pts Won","Share" ]].fillna(0)
player_to_check = 'Dirk Nowitzki'

# Check if the player exists
player_rows = mvps[mvps['Player'] == player_to_check]
print(player_rows)
# Check if the player exists
player_rows = players[players['Player'] == player_to_check]
print(player_rows)
# Out:
#             Player  Year  Pts Won  Share
# 200  Dirk Nowitzki  2002       31  0.025
# 217  Dirk Nowitzki  2003       43  0.036
# 235  Dirk Nowitzki  2004        4  0.003
# 242  Dirk Nowitzki  2005      349  0.275
# 258  Dirk Nowitzki  2006      544  0.435
# 267  Dirk Nowitzki  2007     1138  0.882
# 294  Dirk Nowitzki  2008        5  0.004
# 310  Dirk Nowitzki  2009        3  0.002
# 319  Dirk Nowitzki  2010       55  0.045
# 333  Dirk Nowitzki  2011      113  0.093
# 352  Dirk Nowitzki  2012        4  0.003
# 385  Dirk Nowitzki  2014        7  0.006
#        Unnamed: 0   Rk         Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 4440          340  282  Dirk Nowitzki  PF  20  DAL  47  24  20.4  2.9  ...
# 4974          347  292  Dirk Nowitzki  PF  21  DAL  82  81  35.8  6.3  ...
# 5517          374  293  Dirk Nowitzki  PF  22  DAL  82  82  38.1  7.2  ...
# 6048          347  297  Dirk Nowitzki   C  23  DAL  76  76  38.0  7.9  ...
# ...

# %%
combaind
# Out:
#        Unnamed: 0   Rk          Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             164  135      A.C. Green  PF  27  LAL  82  21  26.4  3.1  ...
# 1             174  141      A.C. Green  PF  28  LAL  82  53  35.4  4.7  ...
# 2             157  137      A.C. Green  PF  29  LAL  82  55  34.4  4.6  ...
# 3             177  149      A.C. Green  PF  30  PHO  82  55  34.5  5.7  ...
# 4             165  142      A.C. Green  SF  31  PHO  82  52  32.8  3.8  ...
# ...           ...  ...             ...  ..  ..  ...  ..  ..   ...  ...  ...
# 15231         394  336  Željko Rebrača   C  29  DET  74   4  15.9  2.6  ...
# 15232         374  316  Željko Rebrača   C  30  DET  30  12  16.3  2.7  ...
# 15233         452  338  Željko Rebrača   C  31  ATL  24   2  11.4  1.4  ...
# 15234         446  350  Željko Rebrača   C  32  LAC  58   2  16.0  2.3  ...
# 15235         433  344  Željko Rebrača   C  33  LAC  29   2  14.2  1.8  ...
#
# ...

# %%
teams= pd.read_csv("teams.csv")

# %%
name_changes = {
    ('Seattle SuperSonics', 2008): 'Oklahoma City Thunder',
    ('Charlotte Bobcats', 2014): 'Charlotte Hornets',  # Charlotte Bobcats changed back to Charlotte Hornets in 2014
    ('New Orleans Hornets', 2013): 'New Orleans Pelicans',
    ('New Jersey Nets', 2012): 'Brooklyn Nets',
    ('Vancouver Grizzlies', 2001): 'Memphis Grizzlies',
    ('Washington Bullets', 1997): 'Washington Wizards'
}

for (old_name, change_year), new_name in name_changes.items():
    teams.loc[(teams['Team'] == old_name) & (teams['Year'] > change_year), 'Team'] = new_name

# %%
teams["Team"] =teams["Team"].str.replace("*","",regex = False)

# %%
rows_2023 = teams[teams['Team'] == "Charlotte Bobcats"]
rows_2023
# Out:
#      Unnamed: 0   W   L   W/L%    GB  PS/G   PA/G    SRS  Year  \
# 409          13  18  64  0.220  41.0  94.3  100.2  -6.15  2005
# 439          13  26  56  0.317  26.0  96.9  100.9  -3.90  2006
# 469          13  33  49  0.402  11.0  96.9  100.6  -3.97  2007
# 499          13  32  50  0.390  20.0  97.1  101.4  -4.49  2008
# 529          13  35  47  0.427  24.0  93.6   94.9  -1.20  2009
# 559          13  44  38  0.537  15.0  95.3   93.8   1.30  2010
# 589          13  34  48  0.415  24.0  93.3   97.3  -4.08  2011
# 620          14   7  59  0.106  39.0  87.0  100.9 -13.96  2012
# 649          13  21  61  0.256  45.0  93.4  102.7  -9.29  2013
# 678          12  43  39  0.524  11.0  96.9   97.1  -0.89  2014
#
#                   Team
# 409  Charlotte Bobcats
# 439  Charlotte Bobcats
# 469  Charlotte Bobcats
# 499  Charlotte Bobcats
# 529  Charlotte Bobcats
# 559  Charlotte Bobcats
# 589  Charlotte Bobcats
# 620  Charlotte Bobcats
# 649  Charlotte Bobcats
# 678  Charlotte Bobcats

# %%
teams["Team"].unique()
# Out:
# array(['Boston Celtics', 'Philadelphia 76ers', 'New York Knicks',
#        'Washington Bullets', 'New Jersey Nets', 'Miami Heat',
#        'Chicago Bulls', 'Detroit Pistons', 'Milwaukee Bucks',
#        'Atlanta Hawks', 'Indiana Pacers', 'Cleveland Cavaliers',
#        'Charlotte Hornets', 'San Antonio Spurs', 'Utah Jazz',
#        'Houston Rockets', 'Orlando Magic', 'Minnesota Timberwolves',
#        'Dallas Mavericks', 'Denver Nuggets', 'Portland Trail Blazers',
#        'Los Angeles Lakers', 'Phoenix Suns', 'Golden State Warriors',
#        'Seattle SuperSonics', 'Los Angeles Clippers', 'Sacramento Kings',
#        'Toronto Raptors', 'Vancouver Grizzlies', 'Washington Wizards',
#        'Memphis Grizzlies', 'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans'], dtype=object)

# %%
combaind["Tm"].unique()
# Out:
# array(['LAL', 'PHO', 'DAL', 'MIA', 'CLE', 'WSB', 'MIL', 'CHI', 'GSW',
#        'IND', 'WAS', 'MIN', 'BOS', 'ATL', 'HOU', 'DEN', 'ORL', 'NOH',
#        'TOR', 'SAC', 'CHO', 'PHI', 'POR', 'DET', 'OKC', 'UTA', 'VAN',
#        'SEA', 'NJN', 'NOK', 'LAC', 'CHA', 'MEM', 'NYK', 'NOP', 'BRK',
#        'SAS', 'CHH'], dtype=object)

# %%
nicknames = {
    'ATL': 'Atlanta Hawks',
    'BRK': 'Brooklyn Nets',
    'BKN': 'Brooklyn Nets',
    'BOS': 'Boston Celtics',
    'CHA': 'Charlotte Bobcats',
    'CHH': 'Charlotte Hornets',
    'CHO': 'Charlotte Hornets',
    'CHI': 'Chicago Bulls',
    'CLE': 'Cleveland Cavaliers',
    'DAL': 'Dallas Mavericks',
    'DEN': 'Denver Nuggets',
    'DET': 'Detroit Pistons',
    'GSW': 'Golden State Warriors',
    'HOU': 'Houston Rockets',
    'IND': 'Indiana Pacers',
    'LAC': 'Los Angeles Clippers',
    'LAL': 'Los Angeles Lakers',
    'MEM': 'Memphis Grizzlies',
    'MIA': 'Miami Heat',
    'MIL': 'Milwaukee Bucks',
    'MIN': 'Minnesota Timberwolves',
    'NJN': 'New Jersey Nets',
    'NOH': 'New Orleans Hornets',
    'NOP': 'New Orleans Pelicans',
    'NOK': 'New Orleans/Oklahoma City Hornets',
    'NYK': 'New York Knicks',
    'OKC': 'Oklahoma City Thunder',
    'ORL': 'Orlando Magic',
    'PHI': 'Philadelphia 76ers',
    'PHX': 'Phoenix Suns',
    'PHO': 'Phoenix Suns',
    'POR': 'Portland Trail Blazers',
    'SEA': 'Seattle SuperSonics',
    'SAC': 'Sacramento Kings',
    'SAS': 'San Antonio Spurs',
    'TOR': 'Toronto Raptors',
    'UTA': 'Utah Jazz',
    'VAN': 'Vancouver Grizzlies',
    'WAS': 'Washington Wizards',
    'WSB': 'Washington Bullets'
}

# %%
combaind['Team'] = combaind['Tm'].map(nicknames)

# %%
combaind
# Out:
#        Unnamed: 0   Rk          Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             164  135      A.C. Green  PF  27  LAL  82  21  26.4  3.1  ...
# 1             174  141      A.C. Green  PF  28  LAL  82  53  35.4  4.7  ...
# 2             157  137      A.C. Green  PF  29  LAL  82  55  34.4  4.6  ...
# 3             177  149      A.C. Green  PF  30  PHO  82  55  34.5  5.7  ...
# 4             165  142      A.C. Green  SF  31  PHO  82  52  32.8  3.8  ...
# ...           ...  ...             ...  ..  ..  ...  ..  ..   ...  ...  ...
# 15231         394  336  Željko Rebrača   C  29  DET  74   4  15.9  2.6  ...
# 15232         374  316  Željko Rebrača   C  30  DET  30  12  16.3  2.7  ...
# 15233         452  338  Željko Rebrača   C  31  ATL  24   2  11.4  1.4  ...
# 15234         446  350  Željko Rebrača   C  32  LAC  58   2  16.0  2.3  ...
# 15235         433  344  Željko Rebrača   C  33  LAC  29   2  14.2  1.8  ...
#
# ...

# %%
stats = combaind.merge(teams, how="outer",on=["Team", "Year"])

# %%
stats
# Out:
#        Unnamed: 0_x   Rk             Player Pos Age   Tm   G  GS    MP   FG  \
# 0               338  283         Doc Rivers  PG  29  ATL  79  79  32.7  5.6
# 1               424  361  Dominique Wilkins  SF  31  ATL  81  81  38.0  9.5
# 2               134  110      Duane Ferrell  SF  25  ATL  78   2  14.9  2.2
# 3               236  196       Gary Leonard   C  23  ATL   4   0   2.3  0.0
# 4                25   23        John Battle  SG  28  ATL  79   2  23.6  5.0
# ...             ...  ...                ...  ..  ..  ...  ..  ..   ...  ...
# 15231           456  349       Monte Morris  PG  27  WAS  62  61  27.3  4.0
# 15232           312  237    Quenton Jackson  PG  24  WAS   9   0  15.0  2.1
# 15233           214  162         Taj Gibson   C  37  WAS  49   2   9.8  1.3
# 15234           110   82   Vernon Carey Jr.   C  21  WAS  11   0   2.5  0.2
# 15235           136  101       Xavier Cooks  PF  27  WAS  10   1  12.6  1.7
#
# ...

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15236 entries, 0 to 15235
# Data columns (total 43 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0_x  15236 non-null  int64
#  1   Rk            15236 non-null  object
#  2   Player        15236 non-null  object
#  3   Pos           15236 non-null  object
#  4   Age           15236 non-null  object
#  5   Tm            15236 non-null  object
#  6   G             15236 non-null  object
#  7   GS            15236 non-null  object
#  8   MP            15236 non-null  object
#  9   FG            15236 non-null  object
#  10  FGA           15236 non-null  object
#  11  FG%           15175 non-null  object
#  12  3P            15236 non-null  object
#  13  3PA           15236 non-null  object
#  14  3P%           13134 non-null  object
#  15  2P            15236 non-null  object
#  16  2PA           15236 non-null  object
#  17  2P%           15131 non-null  object
# ...

# %%
stats.dtypes
# Out:
# Unnamed: 0_x      int64
# Rk               object
# Player           object
# Pos              object
# Age              object
# Tm               object
# G                object
# GS               object
# MP               object
# FG               object
# FGA              object
# FG%              object
# 3P               object
# 3PA              object
# 3P%              object
# 2P               object
# 2PA              object
# 2P%              object
# eFG%             object
# FT               object
# FTA              object
# FT%              object
# ORB              object
# DRB              object
# TRB              object
# AST              object
# STL              object
# BLK              object
# TOV              object
# PF               object
# PTS              object
# Year              int64
# Pts Won         float64
# Share           float64
# Team             object
# Unnamed: 0_y      int64
# W                 int64
# L                 int64
# ...

# %%
del stats["Unnamed: 0_y"]

# %%
stats
# Out:
#        Unnamed: 0_x   Rk             Player Pos Age   Tm   G  GS    MP   FG  \
# 0               338  283         Doc Rivers  PG  29  ATL  79  79  32.7  5.6
# 1               424  361  Dominique Wilkins  SF  31  ATL  81  81  38.0  9.5
# 2               134  110      Duane Ferrell  SF  25  ATL  78   2  14.9  2.2
# 3               236  196       Gary Leonard   C  23  ATL   4   0   2.3  0.0
# 4                25   23        John Battle  SG  28  ATL  79   2  23.6  5.0
# ...             ...  ...                ...  ..  ..  ...  ..  ..   ...  ...
# 15231           456  349       Monte Morris  PG  27  WAS  62  61  27.3  4.0
# 15232           312  237    Quenton Jackson  PG  24  WAS   9   0  15.0  2.1
# 15233           214  162         Taj Gibson   C  37  WAS  49   2   9.8  1.3
# 15234           110   82   Vernon Carey Jr.   C  21  WAS  11   0   2.5  0.2
# 15235           136  101       Xavier Cooks  PF  27  WAS  10   1  12.6  1.7
#
# ...

# %%
stats=stats.apply(pd.to_numeric,errors="ignore")
# Out:
# C:\Users\wwera\AppData\Local\Temp\ipykernel_10516\2354463524.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   stats=stats.apply(pd.to_numeric,errors="ignore")

# %%
stats.dtypes
# Out:
# Unnamed: 0_x      int64
# Rk                int64
# Player           object
# Pos              object
# Age               int64
# Tm               object
# G                 int64
# GS                int64
# MP              float64
# FG              float64
# FGA             float64
# FG%             float64
# 3P              float64
# 3PA             float64
# 3P%             float64
# 2P              float64
# 2PA             float64
# 2P%             float64
# eFG%            float64
# FT              float64
# FTA             float64
# FT%             float64
# ORB             float64
# DRB             float64
# TRB             float64
# AST             float64
# STL             float64
# BLK             float64
# TOV             float64
# PF              float64
# PTS             float64
# Year              int64
# Pts Won         float64
# Share           float64
# Team             object
# W                 int64
# L                 int64
# W/L%            float64
# ...

# %%
stats["GB"].unique()
# Out:
# array(['18.0', '29.0', '14.0', '—', '10.0', '26.0', '13.0', '12.0', '2.0',
#        '28.0', '27.0', '17.0', '15.0', '33.0', '46.0', '6.0', '22.0',
#        '16.0', '20.0', '21.0', '3.0', '25.0', '19.0', '5.0', '11.0',
#        '23.0', '12.5', '9.0', '8.0', '4.0', '35.0', '31.0', '1.0', '7.0',
#        '41.0', '24.0', '39.0', '45.0', '36.0', '37.0', '38.0', '4.5',
#        '30.0', '43.0', '25.5', '44.0', '40.0', '42.0', '2.5', '51.0',
#        '34.0', '32.0', '20.5', '32.5', '48.0', '52.0', '3.5', '56.0',
#        '10.5', '47.0', '11.5', '22.5', '1.5', '50.0', '21.5', '18.5'],
#       dtype=object)

# %%
stats["GB"] =stats["GB"].str.replace("—","0")

# %%
stats["GB"].unique()
# Out:
# array(['18.0', '29.0', '14.0', '0', '10.0', '26.0', '13.0', '12.0', '2.0',
#        '28.0', '27.0', '17.0', '15.0', '33.0', '46.0', '6.0', '22.0',
#        '16.0', '20.0', '21.0', '3.0', '25.0', '19.0', '5.0', '11.0',
#        '23.0', '12.5', '9.0', '8.0', '4.0', '35.0', '31.0', '1.0', '7.0',
#        '41.0', '24.0', '39.0', '45.0', '36.0', '37.0', '38.0', '4.5',
#        '30.0', '43.0', '25.5', '44.0', '40.0', '42.0', '2.5', '51.0',
#        '34.0', '32.0', '20.5', '32.5', '48.0', '52.0', '3.5', '56.0',
#        '10.5', '47.0', '11.5', '22.5', '1.5', '50.0', '21.5', '18.5'],
#       dtype=object)

# %%
stats["GB"] = pd.to_numeric(stats["GB"])

# %%
stats.dtypes
# Out:
# Unnamed: 0_x      int64
# Rk                int64
# Player           object
# Pos              object
# Age               int64
# Tm               object
# G                 int64
# GS                int64
# MP              float64
# FG              float64
# FGA             float64
# FG%             float64
# 3P              float64
# 3PA             float64
# 3P%             float64
# 2P              float64
# 2PA             float64
# 2P%             float64
# eFG%            float64
# FT              float64
# FTA             float64
# FT%             float64
# ORB             float64
# DRB             float64
# TRB             float64
# AST             float64
# STL             float64
# BLK             float64
# TOV             float64
# PF              float64
# PTS             float64
# Year              int64
# Pts Won         float64
# Share           float64
# Team             object
# W                 int64
# L                 int64
# W/L%            float64
# ...

# %%
stats
# Out:
#        Unnamed: 0_x   Rk             Player Pos  Age   Tm   G  GS    MP   FG  \
# 0               338  283         Doc Rivers  PG   29  ATL  79  79  32.7  5.6
# 1               424  361  Dominique Wilkins  SF   31  ATL  81  81  38.0  9.5
# 2               134  110      Duane Ferrell  SF   25  ATL  78   2  14.9  2.2
# 3               236  196       Gary Leonard   C   23  ATL   4   0   2.3  0.0
# 4                25   23        John Battle  SG   28  ATL  79   2  23.6  5.0
# ...             ...  ...                ...  ..  ...  ...  ..  ..   ...  ...
# 15231           456  349       Monte Morris  PG   27  WAS  62  61  27.3  4.0
# 15232           312  237    Quenton Jackson  PG   24  WAS   9   0  15.0  2.1
# 15233           214  162         Taj Gibson   C   37  WAS  49   2   9.8  1.3
# 15234           110   82   Vernon Carey Jr.   C   21  WAS  11   0   2.5  0.2
# 15235           136  101       Xavier Cooks  PF   27  WAS  10   1  12.6  1.7
#
# ...

# %%
del stats["Unnamed: 0_x"]
del stats["Rk"	]

# %%
stats
# Out:
#                   Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0             Doc Rivers  PG   29  ATL  79  79  32.7  5.6  12.9  0.435  ...
# 1      Dominique Wilkins  SF   31  ATL  81  81  38.0  9.5  20.2  0.470  ...
# 2          Duane Ferrell  SF   25  ATL  78   2  14.9  2.2   4.6  0.489  ...
# 3           Gary Leonard   C   23  ATL   4   0   2.3  0.0   0.0    NaN  ...
# 4            John Battle  SG   28  ATL  79   2  23.6  5.0  10.9  0.461  ...
# ...                  ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 15231       Monte Morris  PG   27  WAS  62  61  27.3  4.0   8.3  0.480  ...
# 15232    Quenton Jackson  PG   24  WAS   9   0  15.0  2.1   4.7  0.452  ...
# 15233         Taj Gibson   C   37  WAS  49   2   9.8  1.3   2.6  0.520  ...
# 15234   Vernon Carey Jr.   C   21  WAS  11   0   2.5  0.2   0.7  0.250  ...
# 15235       Xavier Cooks  PF   27  WAS  10   1  12.6  1.7   2.8  0.607  ...
#
# ...

# %%
stats.to_csv("player_mvp_stats.csv")

# %%
highest_score = stats[stats["G"]> 70].sort_values("PTS", ascending = False).head(10)

# %%
highest_score
# Out:
#                   Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 5297        James Harden  PG   29  HOU  78  78  36.8  10.8  24.5  0.442  ...
# 6637         Kobe Bryant  SG   27  LAL  80  80  41.0  12.2  27.2  0.450  ...
# 11043      Allen Iverson  PG   30  PHI  72  72  43.1  11.3  25.3  0.447  ...
# 1759      Michael Jordan  SG   29  CHI  78  78  39.3  12.7  25.7  0.495  ...
# 10492      Tracy McGrady  SG   23  ORL  75  74  39.4  11.1  24.2  0.457  ...
# 10127       Kevin Durant  SF   25  OKC  81  81  38.5  10.5  20.8  0.503  ...
# 6651         Kobe Bryant  SG   28  LAL  77  77  40.8  10.6  22.8  0.463  ...
# 10179  Russell Westbrook  PG   28  OKC  81  81  34.6  10.2  24.0  0.425  ...
# 1733      Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539  ...
# 2472        LeBron James  SF   21  CLE  79  79  42.5  11.1  23.1  0.480  ...
#
#        Pts Won  Share                   Team   W   L   W/L%    GB   PS/G  \
# ...

# %%
highest_score.plot.bar("Player","PTS")
# Out:
# <Axes: xlabel='Player'>

# %%
highest_scoring= stats.groupby("Year").apply(lambda x: x.sort_values("PTS",ascending =False).head(1))

# %%
highest_scoring
# Out:
#                        Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# Year
# 1991 1733      Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539
# 1992 1746      Michael Jordan  SG   28  CHI  80  80  38.8  11.8  22.7  0.519
# 1993 1759      Michael Jordan  SG   29  CHI  78  78  39.3  12.7  25.7  0.495
# 1994 12905     David Robinson   C   28  SAS  80  80  40.5  10.5  20.7  0.507
# 1995 10368   Shaquille O'Neal   C   22  ORL  79  79  37.0  11.8  20.2  0.583
# 1996 1806      Michael Jordan  SG   32  CHI  82  82  37.7  11.2  22.6  0.495
# 1997 1820      Michael Jordan  SG   33  CHI  82  82  37.9  11.2  23.1  0.486
# 1998 1834      Michael Jordan  SG   34  CHI  82  82  38.8  10.7  23.1  0.465
# 1999 10936      Allen Iverson  SG   23  PHI  48  48  41.5   9.1  22.0  0.412
# 2000 6554    Shaquille O'Neal   C   27  LAL  79  79  40.0  12.1  21.1  0.574
# 2001 10967      Allen Iverson  SG   25  PHI  71  71  42.0  10.7  25.5  0.420
# ...

# %%
highest_scoring.plot.bar("Player","PTS")
# Out:
# <Axes: xlabel='Player'>
